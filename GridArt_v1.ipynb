# %% [markdown]
# ## GridArt
# version 1 by BennyFace.

# %%
# this program makes use of image_grid, if you need it uncomment the line below.
# !pip install image_grid

# %%
#imports 

import os,shutil
from pathlib import Path
import zipfile
import random
import numpy as np
from PIL import Image  
from datetime import datetime

# %% [markdown]
# Please select grid layout and image size. Copy source images to /src_data

# %%
# variables
GRID_LAYOUT = "SpaceInvader"   # pick from "Skull" or "SpaceInvader"
IMG_SIZE = 320

# %%
# folders
home_path = os.getcwd()
SOURCE_FOLDER = home_path + "/src_data"
out_path = home_path + "/output"
job_name = datetime.now().isoformat()
working_folder = out_path + '/' + job_name
OUT_FILE = working_folder + "_FINAL_GRID.png"

# %%
# create the output folder
os.chdir(out_path)
if not os.path.exists(job_name):
    os.mkdir(job_name)
    
# create list of possible source images to use.
src_image_list = []
for (_, dirs, files) in os.walk(SOURCE_FOLDER):
    src_image_list.append(files)

# %%
# define the skull grid
def skull():
    row1 = []
    row2 = []
    row3 = [149]
    row4 = [214]
    row5 = [279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292]
    row6 = [348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358]
    row7 = [408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,426,435,436,437,438,439,440,441,442]
    row8 = [473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 509, 510, 511, 512, 513]
    row9 = [536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 574, 575, 576, 577, 578]
    row10 = [597, 599, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 639, 640, 641]
    row11 = [659, 660, 661,662,663,664,666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 699, 700, 703, 704, 705]
    row12 = [724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770]
    row13 = [790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834]
    row14 = [860, 861, 862, 863, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900]
    row15 = [925, 926, 927, 928, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 963, 964, 965]
    row16 = [985, 986, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030]
    row17 = [1050, 1051, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095]
    row18 = [1115, 1116, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1165]
    row19 = [1174, 1175, 1176, 1177, 1178, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1228,1229,1230]
    row56 = [3604, 3605, 3606, 3607, 3609, 3610, 3611, 3614, 3615, 3616, 3617]
    row57 = [3669, 3670, 3671, 3672, 3674, 3675, 3676, 3679, 3680, 3681, 3682]
    row58 = [3734, 3735, 3736, 3737, 3739, 3740, 3741, 3742, 3744, 3745, 3746, 3747]
    row59 = [3798, 3799, 3800, 3801, 3802, 3804, 3810]
    row60 = [3863, 3865, 3866, 3867]
    row61 = [3928, 3930, 3931, 3932]
    row62 = [3995,3996]
    row63 = []
    row64 = []
    row65 = []

    all_rows = row1 + row2 + row3 + row4 + row5 + row6 + row7 + row8 + row9 + row10 + row11 + row12 + row13 + row14 + row15 + row16 + row17 + row18 + row19 + row20 + row21 + row22 + row23 + row24 + row25 + row26 + row27 + row28 + row29 + row30 + row31 + row32 + row33 + row34 + row35 + row36 + row37 + row38 + row39 + row40 + row41 + row42 + row43 + row44 + row45 + row46 + row47 + row48 + row49 + row50 + row51 + row52 + row53 + row54 + row55 + row56 + row57 + row58 + row59 + row60 + row61 + row62 + row63 + row64 + row65

    every_tile = [str(num).rjust(4,"0") for num in list(range(1,4226))]
    background_tiles = list(np.setdiff1d(every_tile, all_rows))
    pic_tile = [str(pic).rjust(4,"0") for pic in all_rows if pic not in every_tile]
    additup = 1
    os.chdir(out_path)

    # create the black images
    for image_number in background_tiles:
        img  = Image.new( mode = "RGB", size = (IMG_SIZE, IMG_SIZE) )
        image_name = working_folder + '/' + str(image_number).rjust(4,"0") + '.png'
        img.save(image_name)
        additup+=1
    
    get_ipython().run_line_magic('cd', '$SOURCE_FOLDER')
    pic_number = 0   
    for _ in range(len(pic_tile)-1):
        shutil.copy(src_image_list[0][pic_number], f"{working_folder}/{pic_tile[pic_number]}.png")
        pic_number = pic_number + 1
        
    get_ipython().run_line_magic('cd', home_path)
    get_ipython().system('python image-grid.py -f $working_folder -o $OUT_FILE -bs 5 -bsa 5 -bc 0 -c 65 -w 10000   ')

# %%
# define space invader grid
def invader():
    row1 = []
    row2 = [17,23]
    row3 = [31,32,33,34,35]
    row4 = [43,45,46,47,49]
    row5 = [55,56,57,58,59,60,61,62,63]
    row6 = [67,68,69,70,71,72,73,74,75,76,77]
    row7 = [80,82,83,84,86,87,88,90]
    row8 = [93,95,101,103]
    row9 = [109,110,112,113]
    row10 = []
    
    all_rows = row1 + row2 + row3 + row4 + row5 + row6 + row7 + row8 + row9 + row10

    every_tile = [str(num).rjust(3,"0") for num in list(range(1,131))]
    background_tiles = list(np.setdiff1d(every_tile, all_rows))
    pic_tile = [str(pic).rjust(3,"0") for pic in all_rows if pic not in every_tile]
    additup = 1
    
    os.chdir(out_path)

    for image_number in background_tiles:
        img  = Image.new( mode = "RGB", size = (IMG_SIZE, IMG_SIZE) )
        image_name = working_folder + '/' + str(image_number).rjust(3,"0") + '.png'
        img.save(image_name)
        additup+=1
    
    get_ipython().run_line_magic('cd', '$SOURCE_FOLDER')
    
    #     # pattern for Space Invader
    shutil.copy(src_image_list[0][0], working_folder+'/017.png')
    shutil.copy(src_image_list[0][1], working_folder+'/023.png')
    shutil.copy(src_image_list[0][2], working_folder+'/031.png')
    shutil.copy(src_image_list[0][3], working_folder+'/032.png')
    shutil.copy(src_image_list[0][4], working_folder+'/033.png')
    shutil.copy(src_image_list[0][5], working_folder+'/034.png')
    shutil.copy(src_image_list[0][6], working_folder+'/035.png')
    shutil.copy(src_image_list[0][7], working_folder+'/043.png')
    shutil.copy(src_image_list[0][8], working_folder+'/045.png')
    shutil.copy(src_image_list[0][9], working_folder+'/046.png')
    shutil.copy(src_image_list[0][10], working_folder+'/047.png')
    shutil.copy(src_image_list[0][11], working_folder+'/049.png')
    shutil.copy(src_image_list[0][12], working_folder+'/055.png')
    shutil.copy(src_image_list[0][13], working_folder+'/056.png')
    shutil.copy(src_image_list[0][14], working_folder+'/057.png')
    shutil.copy(src_image_list[0][15], working_folder+'/058.png')
    shutil.copy(src_image_list[0][16], working_folder+'/059.png')
    shutil.copy(src_image_list[0][17], working_folder+'/060.png')
    shutil.copy(src_image_list[0][18], working_folder+'/061.png')
    shutil.copy(src_image_list[0][19], working_folder+'/062.png')
    shutil.copy(src_image_list[0][20], working_folder+'/063.png')
    shutil.copy(src_image_list[0][21], working_folder+'/067.png')
    shutil.copy(src_image_list[0][22], working_folder+'/068.png')
    shutil.copy(src_image_list[0][23], working_folder+'/069.png')
    shutil.copy(src_image_list[0][24], working_folder+'/070.png')
    shutil.copy(src_image_list[0][25], working_folder+'/071.png')
    shutil.copy(src_image_list[0][26], working_folder+'/072.png')
    shutil.copy(src_image_list[0][27], working_folder+'/073.png')
    shutil.copy(src_image_list[0][28], working_folder+'/074.png')
    shutil.copy(src_image_list[0][29], working_folder+'/075.png')
    shutil.copy(src_image_list[0][30], working_folder+'/076.png')
    shutil.copy(src_image_list[0][31], working_folder+'/077.png')
    shutil.copy(src_image_list[0][32], working_folder+'/080.png')
    shutil.copy(src_image_list[0][33], working_folder+'/082.png')
    shutil.copy(src_image_list[0][34], working_folder+'/083.png')
    shutil.copy(src_image_list[0][35], working_folder+'/084.png')
    shutil.copy(src_image_list[0][36], working_folder+'/085.png')
    shutil.copy(src_image_list[0][37], working_folder+'/086.png')
    shutil.copy(src_image_list[0][38], working_folder+'/087.png')
    shutil.copy(src_image_list[0][39], working_folder+'/088.png')
    shutil.copy(src_image_list[0][40], working_folder+'/090.png')
    shutil.copy(src_image_list[0][41], working_folder+'/093.png')
    shutil.copy(src_image_list[0][42], working_folder+'/095.png')
    shutil.copy(src_image_list[0][43], working_folder+'/101.png')
    shutil.copy(src_image_list[0][44], working_folder+'/103.png')
    shutil.copy(src_image_list[0][45], working_folder+'/109.png')
    shutil.copy(src_image_list[0][46], working_folder+'/110.png')
    shutil.copy(src_image_list[0][47], working_folder+'/112.png')
    shutil.copy(src_image_list[0][48], working_folder+'/113.png')

    
    get_ipython().run_line_magic('cd', home_path)
    get_ipython().system('python image-grid.py -f $working_folder -o $OUT_FILE -bs 5 -bsa 5 -bc 0 -c 13 -w 10000  ')

# %%
# create the grid image.

if GRID_LAYOUT == "Skull":
    skull()
elif GRID_LAYOUT == "SpaceInvader":
    invader()
else:
    pass


print("All Done")
# Out:
# /home/bennyface/skullgrid/src_data
# /home/bennyface/skullgrid
# saved /home/bennyface/skullgrid/output/2023-02-06T13:20:10.247213_FINAL_GRID.png, (7695, 10002, 4), 41.1MiB
# All Done
